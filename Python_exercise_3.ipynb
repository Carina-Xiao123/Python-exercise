# %%
import pandas as pd
import pandas
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoLarsCV
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,accuracy_score
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
alldata = pd.read_csv(open('drive/My Drive/Colab Notebooks/lecture folder/finalmaster-ratios.csv','rb'))
alldata.head(10)
# Out:
#    # Purchases  B01001001   B01001002  ...  B19001015  B19001016   B19001017
# 0           22     206252  469.226965  ...  36.440765  23.446284   21.197485
# 1            7      61399  486.538869  ...  33.000508  33.169741   24.792689
# 2            3      73170  489.859232  ...  20.125056  11.890525   16.537397
# 3           94     251724  505.585483  ...  43.731067  38.851729   40.427349
# 4            0      37382  495.586111  ...  36.118530  31.603714   19.648989
# 5           19     230108  499.217759  ...  56.045708  39.017601   28.859106
# 6           11     928405  493.339652  ...  66.729965  71.766845   60.436761
# 7            2      15890  498.237886  ...   0.000000   0.000000    0.000000
# 8            0      24327  475.562133  ...  40.637699  16.359279   10.003126
# 9         2861   19979950  483.276184  ...  63.997025  80.800359  102.752258
#
# [10 rows x 190 columns]

# %%
allvariablenames = list(alldata.columns.values)
allvariablenames
# Out:
# ['# Purchases',
#  'B01001001',
#  'B01001002',
#  'B01001003',
#  'B01001004',
#  'B01001005',
#  'B01001006',
#  'B01001007',
#  'B01001008',
#  'B01001009',
#  'B01001010',
#  'B01001011',
#  'B01001012',
#  'B01001013',
#  'B01001014',
#  'B01001015',
#  'B01001016',
#  'B01001017',
#  'B01001018',
#  'B01001019',
#  'B01001020',
#  'B01001021',
#  'B01001022',
#  'B01001023',
#  'B01001024',
#  'B01001025',
#  'B01001026',
#  'B01001027',
#  'B01001028',
#  'B01001029',
#  'B01001030',
#  'B01001031',
#  'B01001032',
#  'B01001033',
#  'B01001034',
#  'B01001035',
#  'B01001036',
#  'B01001037',
#  'B01001038',
#  'B01001039',
#  'B01001040',
#  'B01001041',
#  'B01001042',
#  'B01001043',
#  'B01001044',
#  'B01001045',
#  'B01001046',
#  'B01001047',
#  'B01001048',
#  'B01001049',
#  'B02001001',
#  'B02001002',
#  'B02001003',
#  'B02001004',
#  'B02001005',
#  'B02001006',
#  'B02001007',
#  'B02001008',
#  'B02001009',
#  'B02001010',
#  'B12001001',
#  'B12001002',
# ...

# %%
listofallpredictors=allvariablenames[8:]
listofallpredictors
# Out:
# ['B01001008',
#  'B01001009',
#  'B01001010',
#  'B01001011',
#  'B01001012',
#  'B01001013',
#  'B01001014',
#  'B01001015',
#  'B01001016',
#  'B01001017',
#  'B01001018',
#  'B01001019',
#  'B01001020',
#  'B01001021',
#  'B01001022',
#  'B01001023',
#  'B01001024',
#  'B01001025',
#  'B01001026',
#  'B01001027',
#  'B01001028',
#  'B01001029',
#  'B01001030',
#  'B01001031',
#  'B01001032',
#  'B01001033',
#  'B01001034',
#  'B01001035',
#  'B01001036',
#  'B01001037',
#  'B01001038',
#  'B01001039',
#  'B01001040',
#  'B01001041',
#  'B01001042',
#  'B01001043',
#  'B01001044',
#  'B01001045',
#  'B01001046',
#  'B01001047',
#  'B01001048',
#  'B01001049',
#  'B02001001',
#  'B02001002',
#  'B02001003',
#  'B02001004',
#  'B02001005',
#  'B02001006',
#  'B02001007',
#  'B02001008',
#  'B02001009',
#  'B02001010',
#  'B12001001',
#  'B12001002',
#  'B12001003',
#  'B12001004',
#  'B12001005',
#  'B12001006',
#  'B12001007',
#  'B12001008',
#  'B12001009',
#  'B12001010',
# ...

# %%
predictors = alldata[listofallpredictors] 
target = alldata['# Purchases']

# %%
pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=123)

# %%
model= LassoLarsCV(fit_intercept=True, precompute=False, cv=10, positive=False)

# %%
pred=model.fit(pred_train,tar_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/least_angle.py:578: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.496e+00, with an active set of 5 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/least_angle.py:578: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.098e+00, with an active set of 8 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# ...

# %%
predictors_model=pd.DataFrame(listofallpredictors)
predictors_model.columns = ['label']
predictors_model['coeff'] = model.coef_

for index, row in predictors_model.iterrows():
    if row['coeff'] > 0:
        print(row.values)
# Out:
# ['B01001014' 0.8558761066941788]
# ['B01001036' 2.5053482381631653]
# ['B01001037' 0.8892493223320962]
# ['B01001038' 1.5316387928880384]
# ['B02001005' 0.41252295298457853]
# ['B13014026' 0.48004105312075906]
# ['B13014027' 0.6978957445987839]
# ['B13016001' 875149895.329212]
# ['B19001017' 1.4834348068681533]

# %%
# Question 1: The first line above is to show all predictors' columns. The second is to create index "label" that contains all columns.
#The third is to get column coefficient in each column. The for loop is getting the columns and values that coefficient is greater than 0

# %%
# Question 2: B01001014: male aged 40-44. B01001036:female aged 30-34. B01001037: female aged 35-39. B01001038:female aged 40-44
# B02001005: total population with all Asian B0 
#B13014026:unmarried women with bachelor degree B13014027: unmarried women with master or professional degree
#B13016001: women aged 15-50
#B19001017: household income $200,000 or more
# women aged 15-50 tend to buy the most Bobo bars, which means one women aged 15-50 who had a birth in the past 12 months, one more 875149895 unit 
# Bobo bars will be sold

# %%
train_error = mean_squared_error(tar_train, model.predict(pred_train))
print ('training data MSE')
print(train_error)
# Out:
# training data MSE
# 22025.491066757

# %%
test_error = mean_squared_error(tar_test, model.predict(pred_test))
print ('training data MSE')
print(test_error)
# Out:
# training data MSE
# 41549.54803776253

# %%
#Question 3: The two census variables are B13016001(women aged 15-50) and B01001036(women aged 30-34).

# %%
rsquared_train=model.score(pred_train,tar_train)
print ('training data R-square')
print(rsquared_train)
# Out:
# training data R-square
# 0.2400221219784492

# %%
rsquared_test=model.score(pred_test,tar_test)
print ('test data R-square')
print(rsquared_test)
# Out:
# test data R-square
# 0.1758628512005107

# %%
#Question 4； #Training and test mean squared errors are different. Test error is greater than training error.The r-square values between training 
#and test are different as well. Training data can better predict regression model.

# %%
#Question 5: Census data can't predict sales very well, because R-square values for both training and test are not high.

# %%
#Question 6: The y intercept is 22, so the baseline sales number is around 22, which means when all variables are equal to 0, they can still sell
# about 22 Bobo bars.

# %%
print("y interecept:")
print(model.intercept_)
# Out:
# y interecept:
# 22.19738813257551
